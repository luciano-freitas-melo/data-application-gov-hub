# %%
import sys
sys.path.append('../src')

from airflow.clients.cliente_estrutura import ClienteEstrutura
client = ClienteEstrutura()
response = client.get_estrutura_organizacional_resumida(codigo_unidade='7', codigo_poder='1', codigo_esfera='1')
# Out:
# [2025-01-09T21:09:37.836+0100] {_client.py:1025} INFO - HTTP Request: GET https://estruturaorganizacional.dados.gov.br/doc/estrutura-organizacional/resumida?codigoPoder=1&codigoEsfera=1&codigoUnidade=7 "HTTP/1.1 200 OK"

# %%
len(response["unidades"])
# Out:
# 90

# %%
from typing import Any, Dict, List
import json

def flatten(data: Dict[str, Any], parent_key: str = "", sep: str = "_") -> Dict[str, Any]:
    """Flatten nested dictionaries.

    Args:
        data: Dictionary to flatten
        parent_key: Key from parent dictionary
        sep: Separator between nested keys

    Returns:
        Flattened dictionary
    """
    items: List[tuple[str, Any]] = []
    for key, value in data.items():
        new_key = f"{parent_key}{sep}{key}" if parent_key else key

        if isinstance(value, dict):
            items.extend(flatten(value, new_key, sep=sep).items())
        elif isinstance(value, list):
            items.append((new_key, json.dumps(value)))
        else:
            items.append((new_key, value))

    return dict(items)

flattened_test = flatten(response, sep="_")

# %%
type(flattened_test["unidades"])
# Out:
# str

# %%
unidades = response['unidades']

for unidade in unidades:
    if 'IPEA' in unidade["sigla"]:
        print(unidade)
# Out:
# {'codigoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/7', 'codigoUnidadePai': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/308804', 'codigoOrgaoEntidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/7', 'codigoTipoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/tipo-unidade/entidade', 'nome': 'Instituto de Pesquisa Econômica Aplicada', 'sigla': 'IPEA', 'codigoEsfera': 'https://estruturaorganizacional.dados.gov.br/id/esfera/1', 'codigoPoder': 'https://estruturaorganizacional.dados.gov.br/id/poder/1', 'codigoNaturezaJuridica': 'https://estruturaorganizacional.dados.gov.br/id/natureza-juridica/2', 'codigoSubNaturezaJuridica': None, 'nivelNormatizacao': 'LEI_DECRETO', 'versaoConsulta': '114.0.0', 'dataInicialVersaoConsulta': '2024-10-08', 'dataFinalVersaoConsulta': None, 'operacao': None, 'codigoUnidadePaiAnterior': None, 'codigoOrgaoEntidadeAnterior': None}
# {'codigoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/7656', 'codigoUnidadePai': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/7', 'codigoOrgaoEntidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/7', 'codigoTipoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/tipo-unidade/unidade-colegiada', 'nome': 'Conselho Consultivo', 'sigla': 'CC-IPEA', 'codigoEsfera': 'https://estruturaorganizacional.dados.gov.br/id/esfera/1', 'codigoPoder': 'https://estruturaorganizacional.dados.gov.br/id/poder/1', 'codigoNaturezaJuridica': 'https://estruturaorganizacional.dados.gov.br/id/natureza-juridica/2', 'codigoSubNaturezaJuridica': None, 'nivelNormatizacao': 'ATO_INTERNO', 'versaoConsulta': '107.0.191', 'dataInicialVersaoConsulta': '2021-09-24', 'dataFinalVersaoConsulta': None, 'operacao': None, 'codigoUnidadePaiAnterior': None, 'codigoOrgaoEntidadeAnterior': None}
# {'codigoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/7628', 'codigoUnidadePai': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/7', 'codigoOrgaoEntidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/7', 'codigoTipoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/tipo-unidade/unidade-administrativa', 'nome': 'Gabinete', 'sigla': 'GABIN-IPEA', 'codigoEsfera': 'https://estruturaorganizacional.dados.gov.br/id/esfera/1', 'codigoPoder': 'https://estruturaorganizacional.dados.gov.br/id/poder/1', 'codigoNaturezaJuridica': 'https://estruturaorganizacional.dados.gov.br/id/natureza-juridica/2', 'codigoSubNaturezaJuridica': None, 'nivelNormatizacao': 'LEI_DECRETO', 'versaoConsulta': '113.1.0', 'dataInicialVersaoConsulta': '2024-10-01', 'dataFinalVersaoConsulta': None, 'operacao': None, 'codigoUnidadePaiAnterior': None, 'codigoOrgaoEntidadeAnterior': None}
# {'codigoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/255032', 'codigoUnidadePai': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/3561', 'codigoOrgaoEntidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/3561', 'codigoTipoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/tipo-unidade/unidade-administrativa', 'nome': 'Diretoria de Políticas de Educação a Distância', 'sigla': 'DIPEAD', 'codigoEsfera': 'https://estruturaorganizacional.dados.gov.br/id/esfera/1', 'codigoPoder': 'https://estruturaorganizacional.dados.gov.br/id/poder/1', 'codigoNaturezaJuridica': 'https://estruturaorganizacional.dados.gov.br/id/natureza-juridica/4', 'codigoSubNaturezaJuridica': 'https://estruturaorganizacional.dados.gov.br/id/subnatureza-juridica/17', 'nivelNormatizacao': 'ATO_INTERNO', 'versaoConsulta': '112.1.0', 'dataInicialVersaoConsulta': '2022-05-25', 'dataFinalVersaoConsulta': None, 'operacao': None, 'codigoUnidadePaiAnterior': None, 'codigoOrgaoEntidadeAnterior': None}
# {'codigoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/105288', 'codigoUnidadePai': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/104862', 'codigoOrgaoEntidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/100930', 'codigoTipoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/tipo-unidade/unidade-administrativa', 'nome': 'Diretoria de Pesquisa, Extensão e Assistência Estudantil', 'sigla': 'DIPEA', 'codigoEsfera': 'https://estruturaorganizacional.dados.gov.br/id/esfera/1', 'codigoPoder': 'https://estruturaorganizacional.dados.gov.br/id/poder/1', 'codigoNaturezaJuridica': 'https://estruturaorganizacional.dados.gov.br/id/natureza-juridica/4', 'codigoSubNaturezaJuridica': 'https://estruturaorganizacional.dados.gov.br/id/subnatureza-juridica/17', 'nivelNormatizacao': 'ATO_INTERNO', 'versaoConsulta': '114.1.0', 'dataInicialVersaoConsulta': '2022-08-08', 'dataFinalVersaoConsulta': None, 'operacao': None, 'codigoUnidadePaiAnterior': None, 'codigoOrgaoEntidadeAnterior': None}
# {'codigoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/440469', 'codigoUnidadePai': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/84156', 'codigoOrgaoEntidade': 'https://estruturaorganizacional.dados.gov.br/id/unidade-organizacional/41066', 'codigoTipoUnidade': 'https://estruturaorganizacional.dados.gov.br/id/tipo-unidade/unidade-administrativa', 'nome': 'Instituto de Pesquisas do Exército na Amazônia', 'sigla': 'IPEAM', 'codigoEsfera': 'https://estruturaorganizacional.dados.gov.br/id/esfera/1', 'codigoPoder': 'https://estruturaorganizacional.dados.gov.br/id/poder/1', 'codigoNaturezaJuridica': 'https://estruturaorganizacional.dados.gov.br/id/natureza-juridica/3', 'codigoSubNaturezaJuridica': None, 'nivelNormatizacao': 'ATO_INTERNO', 'versaoConsulta': '311.4.0', 'dataInicialVersaoConsulta': '2024-10-28', 'dataFinalVersaoConsulta': None, 'operacao': None, 'codigoUnidadePaiAnterior': None, 'codigoOrgaoEntidadeAnterior': None}

# %%
from airflow.clients.cliente_contratos import ClienteContratos
client = ClienteContratos()
response = client.get_contratos_by_ug(ug_code = '113602')
# Out:
# [2025-01-09T21:10:27.343+0100] {_client.py:1025} INFO - HTTP Request: GET https://contratos.comprasnet.gov.br/api/contrato/ug/113602 "HTTP/1.1 200 OK"

# %%
response[0]
# Out:
# {'id': 4153,
#  'receita_despesa': 'Despesa',
#  'numero': '00014/2019',
#  'contratante': {'orgao_origem': {'codigo': None,
#    'nome': None,
#    'unidade_gestora_origem': {'codigo': None,
#     'nome_resumido': None,
#     'nome': None,
#     'sisg': 'Não',
#     'utiliza_siafi': 'Não',
#     'utiliza_antecipagov': 'Não'}},
#   'orgao': {'codigo': '61201',
#    'nome': 'INSTITUTO DE PESQUISA ECONOMICA APLICADA',
#    'unidade_gestora': {'codigo': '113602',
#     'nome_resumido': 'IPEA/RJ',
#     'nome': 'INSTITUTO DE PESQUISA ECONOMICA APLICADA',
#     'sisg': 'Sim',
#     'utiliza_siafi': 'Sim',
#     'utiliza_antecipagov': 'Sim'}}},
#  'fornecedor': {'tipo': 'JURIDICA',
#   'cnpj_cpf_idgener': '00.000.000/0001-91',
#   'nome': 'BANCO DO BRASIL SA'},
#  'codigo_tipo': '96',
#  'tipo': 'Acordo de Cooperação Técnica (ACT)',
#  'subtipo': None,
#  'prorrogavel': None,
#  'situacao': 'Ativo',
#  'justificativa_inativo': None,
#  'categoria': 'Serviços',
#  'subcategoria': None,
#  'unidades_requisitantes': None,
#  'processo': '03001.002870/2019-10',
#  'objeto': 'O PRESENTE INSTRUMENTO TEM POR OBJETIVO REGULAMENTAR O ESTABELECIMENTO, PELO BANCO, DOS CRITÉRIOS PARA ABERTURA DE DEPÓSITO EM GARANTIA - BLOQUEADO PARA MOVIMENTAÇÃO, DESTINADO A ABRIGAR OS RECURSOS PROVISIONADOS DE RUBRICAS CONSTANTES DA PLANILHA DE CUSTOS E FORMAÇÃO DE PREÇOS DOS CONTRATOS FIRMADOS PELA ADMINISTRAÇÃO PUBLICA FEDERAL, BEM COMO VIABILIZAR O ACESSO DA ADMINISTRAÇÃO PUBLICA FEDERAL AOS SALDOS E EXTRAÍAS DE TODOS OS "EVENTOS".',
#  'amparo_legal': '',
#  'informacao_complementar': None,
#  'codigo_modalidade': 'NAOSEAPLIC',
#  'modalidade': 'Não se Aplica',
#  'unidade_compra': None,
#  'licitacao_numero': None,
#  'sistema_origem_licitacao': None,
#  'data_assinatura': '2020-02-27',
#  'data_publicacao': '2020-03-12',
#  'data_proposta_comercial': None,
#  'vigencia_inicio': '2020-02-27',
#  'vigencia_fim': '2025-02-27',
#  'valor_inicial': '0,01',
#  'valor_global': '0,01',
#  'num_parcelas': 1,
#  'valor_parcela': '0,01',
#  'valor_acumulado': '0,57',
#  'links': {'historico': 'https://contratos.comprasnet.gov.br/api/contrato/4153/historico',
#   'empenhos': 'https://contratos.comprasnet.gov.br/api/contrato/4153/empenhos',
#   'cronograma': 'https://contratos.comprasnet.gov.br/api/contrato/4153/cronograma',
#   'garantias': 'https://contratos.comprasnet.gov.br/api/contrato/4153/garantias',
#   'itens': 'https://contratos.comprasnet.gov.br/api/contrato/4153/itens',
#   'prepostos': 'https://contratos.comprasnet.gov.br/api/contrato/4153/prepostos',
#   'responsaveis': 'https://contratos.comprasnet.gov.br/api/contrato/4153/responsaveis',
#   'despesas_acessorias': 'https://contratos.comprasnet.gov.br/api/contrato/4153/despesas_acessorias',
#   'faturas': 'https://contratos.comprasnet.gov.br/api/contrato/4153/faturas',
#   'ocorrencias': 'https://contratos.comprasnet.gov.br/api/contrato/4153/ocorrencias',
#   'terceirizados': 'https://contratos.comprasnet.gov.br/api/contrato/4153/terceirizados',
#   'arquivos': 'https://contratos.comprasnet.gov.br/api/contrato/4153/arquivos'}}

# %%
from pandas import json_normalize
flattened = json_normalize(response, sep='_').to_dict(orient='records')
print(flattened)
# Out:
# [{'id': 4153, 'receita_despesa': 'Despesa', 'numero': '00014/2019', 'codigo_tipo': '96', 'tipo': 'Acordo de Cooperação Técnica (ACT)', 'subtipo': None, 'prorrogavel': None, 'situacao': 'Ativo', 'justificativa_inativo': None, 'categoria': 'Serviços', 'subcategoria': None, 'unidades_requisitantes': None, 'processo': '03001.002870/2019-10', 'objeto': 'O PRESENTE INSTRUMENTO TEM POR OBJETIVO REGULAMENTAR O ESTABELECIMENTO, PELO BANCO, DOS CRITÉRIOS PARA ABERTURA DE DEPÓSITO EM GARANTIA - BLOQUEADO PARA MOVIMENTAÇÃO, DESTINADO A ABRIGAR OS RECURSOS PROVISIONADOS DE RUBRICAS CONSTANTES DA PLANILHA DE CUSTOS E FORMAÇÃO DE PREÇOS DOS CONTRATOS FIRMADOS PELA ADMINISTRAÇÃO PUBLICA FEDERAL, BEM COMO VIABILIZAR O ACESSO DA ADMINISTRAÇÃO PUBLICA FEDERAL AOS SALDOS E EXTRAÍAS DE TODOS OS "EVENTOS".', 'amparo_legal': '', 'informacao_complementar': None, 'codigo_modalidade': 'NAOSEAPLIC', 'modalidade': 'Não se Aplica', 'unidade_compra': None, 'licitacao_numero': None, 'sistema_origem_licitacao': None, 'data_assinatura': '2020-02-27', 'data_publicacao': '2020-03-12', 'data_proposta_comercial': None, 'vigencia_inicio': '2020-02-27', 'vigencia_fim': '2025-02-27', 'valor_inicial': '0,01', 'valor_global': '0,01', 'num_parcelas': 1, 'valor_parcela': '0,01', 'valor_acumulado': '0,57', 'contratante_orgao_origem_codigo': None, 'contratante_orgao_origem_nome': None, 'contratante_orgao_origem_unidade_gestora_origem_codigo': None, 'contratante_orgao_origem_unidade_gestora_origem_nome_resumido': None, 'contratante_orgao_origem_unidade_gestora_origem_nome': None, 'contratante_orgao_origem_unidade_gestora_origem_sisg': 'Não', 'contratante_orgao_origem_unidade_gestora_origem_utiliza_siafi': 'Não', 'contratante_orgao_origem_unidade_gestora_origem_utiliza_antecipagov': 'Não', 'contratante_orgao_codigo': '61201', 'contratante_orgao_nome': 'INSTITUTO DE PESQUISA ECONOMICA APLICADA', 'contratante_orgao_unidade_gestora_codigo': '113602', 'contratante_orgao_unidade_gestora_nome_resumido': 'IPEA/RJ', 'contratante_orgao_unidade_gestora_nome': 'INSTITUTO DE PESQUISA ECONOMICA APLICADA', 'contratante_orgao_unidade_gestora_sisg': 'Sim', 'contratante_orgao_unidade_gestora_utiliza_siafi': 'Sim', 'contratante_orgao_unidade_gestora_utiliza_antecipagov': 'Sim', 'fornecedor_tipo': 'JURIDICA', 'fornecedor_cnpj_cpf_idgener': '00.000.000/0001-91', 'fornecedor_nome': 'BANCO DO BRASIL SA', 'links_historico': 'https://contratos.comprasnet.gov.br/api/contrato/4153/historico', 'links_empenhos': 'https://contratos.comprasnet.gov.br/api/contrato/4153/empenhos', 'links_cronograma': 'https://contratos.comprasnet.gov.br/api/contrato/4153/cronograma', 'links_garantias': 'https://contratos.comprasnet.gov.br/api/contrato/4153/garantias', 'links_itens': 'https://contratos.comprasnet.gov.br/api/contrato/4153/itens', 'links_prepostos': 'https://contratos.comprasnet.gov.br/api/contrato/4153/prepostos', 'links_responsaveis': 'https://contratos.comprasnet.gov.br/api/contrato/4153/responsaveis', 'links_despesas_acessorias': 'https://contratos.comprasnet.gov.br/api/contrato/4153/despesas_acessorias', 'links_faturas': 'https://contratos.comprasnet.gov.br/api/contrato/4153/faturas', 'links_ocorrencias': 'https://contratos.comprasnet.gov.br/api/contrato/4153/ocorrencias', 'links_terceirizados': 'https://contratos.comprasnet.gov.br/api/contrato/4153/terceirizados', 'links_arquivos': 'https://contratos.comprasnet.gov.br/api/contrato/4153/arquivos'}, {'id': 4980, 'receita_despesa': 'Despesa', 'numero': '00014/2019', 'codigo_tipo': '50', 'tipo': 'Contrato', 'subtipo': None, 'prorrogavel': 'Não', 'situacao': 'Ativo', 'justificativa_inativo': None, 'categoria': 'Serviços', 'subcategoria': None, 'unidades_requisitantes': None, 'processo': '03001.003739/2019-70', 'objeto': 'PRESTAÇÃO DE SERVIÇOS DE TRANSPORTE TERRESTRE DE MATERIAIS E CARGAS, CONFORME CONDIÇÕES ESTABELECIDAS NO TERMO DE REFERÊNCIA E EDITAL.', 'amparo_legal': '', 'informacao_complementar': 'ESTE TERMO DE CONTRATO VINCULA-SE AO EDITAL DO PREGÃO N ...

# %%
for record in flattened:
    for key, value in record.items():
        if type(value) is list:
            print(f"{key}: {value}")

# %%
client = ClienteContratos()
response = client.get_cronograma_by_contrato_id(contrato_id = '4153')
# Out:
# [2025-01-09T21:07:25.922+0100] {cliente_base.py:44} WARNING - API falhou com status Unknown
# [2025-01-09T21:07:26.902+0100] {_client.py:1025} INFO - HTTP Request: GET https://contratos.comprasnet.gov.br/api/contrato/4153/cronograma "HTTP/1.1 200 OK"

# %%
response
# Out:
# [{'id': 1026018,
#   'contrato_id': 4153,
#   'tipo': 'Acordo de Cooperação Técnica (ACT)',
#   'numero': '00014/2019',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CELEBRAÇÃO DO CONTRATO: 0014/2019 DE ACORDO COM PROCESSO NÚMERO: 03001.002870/2019-10',
#   'mesref': '02',
#   'anoref': '2020',
#   'vencimento': '2020-03-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182042,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '07',
#   'anoref': '2020',
#   'vencimento': '2020-08-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182043,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '08',
#   'anoref': '2020',
#   'vencimento': '2020-09-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182044,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '09',
#   'anoref': '2020',
#   'vencimento': '2020-10-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182045,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '10',
#   'anoref': '2020',
#   'vencimento': '2020-11-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182046,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '11',
#   'anoref': '2020',
#   'vencimento': '2020-12-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182047,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '12',
#   'anoref': '2020',
#   'vencimento': '2021-01-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182048,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '01',
#   'anoref': '2021',
#   'vencimento': '2021-02-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182049,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '02',
#   'anoref': '2021',
#   'vencimento': '2021-03-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182050,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '03',
#   'anoref': '2021',
#   'vencimento': '2021-04-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182051,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '04',
#   'anoref': '2021',
#   'vencimento': '2021-05-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182052,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '05',
#   'anoref': '2021',
#   'vencimento': '2021-06-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182053,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '06',
#   'anoref': '2021',
#   'vencimento': '2021-07-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182054,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '07',
#   'anoref': '2021',
#   'vencimento': '2021-08-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182055,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '08',
#   'anoref': '2021',
#   'vencimento': '2021-09-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182056,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '09',
#   'anoref': '2021',
#   'vencimento': '2021-10-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182057,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '10',
#   'anoref': '2021',
#   'vencimento': '2021-11-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182058,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '11',
#   'anoref': '2021',
#   'vencimento': '2021-12-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182059,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '12',
#   'anoref': '2021',
#   'vencimento': '2022-01-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182060,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '01',
#   'anoref': '2022',
#   'vencimento': '2022-02-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182061,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '02',
#   'anoref': '2022',
#   'vencimento': '2022-03-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182062,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '03',
#   'anoref': '2022',
#   'vencimento': '2022-04-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182063,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '04',
#   'anoref': '2022',
#   'vencimento': '2022-05-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182064,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '05',
#   'anoref': '2022',
#   'vencimento': '2022-06-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182065,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '06',
#   'anoref': '2022',
#   'vencimento': '2022-07-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182066,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '07',
#   'anoref': '2022',
#   'vencimento': '2022-08-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182067,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '08',
#   'anoref': '2022',
#   'vencimento': '2022-09-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182068,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '09',
#   'anoref': '2022',
#   'vencimento': '2022-10-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182069,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '10',
#   'anoref': '2022',
#   'vencimento': '2022-11-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182070,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '11',
#   'anoref': '2022',
#   'vencimento': '2022-12-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182071,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '12',
#   'anoref': '2022',
#   'vencimento': '2023-01-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182072,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '01',
#   'anoref': '2023',
#   'vencimento': '2023-02-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182073,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '02',
#   'anoref': '2023',
#   'vencimento': '2023-03-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182074,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '03',
#   'anoref': '2023',
#   'vencimento': '2023-04-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182075,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '04',
#   'anoref': '2023',
#   'vencimento': '2023-05-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182076,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '05',
#   'anoref': '2023',
#   'vencimento': '2023-06-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182077,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '06',
#   'anoref': '2023',
#   'vencimento': '2023-07-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182078,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '07',
#   'anoref': '2023',
#   'vencimento': '2023-08-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182079,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '08',
#   'anoref': '2023',
#   'vencimento': '2023-09-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182080,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '09',
#   'anoref': '2023',
#   'vencimento': '2023-10-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182081,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '10',
#   'anoref': '2023',
#   'vencimento': '2023-11-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182082,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '11',
#   'anoref': '2023',
#   'vencimento': '2023-12-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182083,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '12',
#   'anoref': '2023',
#   'vencimento': '2024-01-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182084,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '01',
#   'anoref': '2024',
#   'vencimento': '2024-02-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182085,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '02',
#   'anoref': '2024',
#   'vencimento': '2024-03-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182086,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '03',
#   'anoref': '2024',
#   'vencimento': '2024-04-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182087,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '04',
#   'anoref': '2024',
#   'vencimento': '2024-05-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182088,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '05',
#   'anoref': '2024',
#   'vencimento': '2024-06-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182089,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '06',
#   'anoref': '2024',
#   'vencimento': '2024-07-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182090,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '07',
#   'anoref': '2024',
#   'vencimento': '2024-08-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182091,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '08',
#   'anoref': '2024',
#   'vencimento': '2024-09-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182092,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '09',
#   'anoref': '2024',
#   'vencimento': '2024-10-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182093,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '10',
#   'anoref': '2024',
#   'vencimento': '2024-11-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182094,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '11',
#   'anoref': '2024',
#   'vencimento': '2024-12-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182095,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '12',
#   'anoref': '2024',
#   'vencimento': '2025-01-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182096,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '01',
#   'anoref': '2025',
#   'vencimento': '2025-02-01',
#   'retroativo': 'Não',
#   'valor': '0,01'},
#  {'id': 1182097,
#   'contrato_id': 4153,
#   'tipo': 'Termo de Apostilamento',
#   'numero': '00001/2020',
#   'receita_despesa': 'Despesa',
#   'observacao': 'CONSTITUI OBJETO DO PRESENTE TERMO DE APOSTILAMENTO A ALTERAÇÃO DOS ENDEREÇOS DA CONTRATANTE, CONSTANTE NO TERMO DE COOPERAÇÃO TÉCNICA Nº 14/2019.\r\nSEI 0315466.',
#   'mesref': '02',
#   'anoref': '2025',
#   'vencimento': '2025-03-01',
#   'retroativo': 'Não',
#   'valor': '0,01'}]

# %%
from requests.auth import HTTPBasicAuth
from zeep import Transport, Client
from requests import Session

BEARER_ENDPOINT = "***REMOVED***"
SOAP_ENDPOINT = "https://apigateway.conectagov.estaleiro.serpro.gov.br/api-consulta-siape/v1/consulta-siape"

session = Session()
session.auth = HTTPBasicAuth('9b47d48f-26fe-49d8-8c74-0a3d91bb06b0', '***REMOVED***')
transport = Transport(session=session)
bearer_client = Client(BEARER_ENDPOINT, transport=transport)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       9 session.auth = HTTPBasicAuth('9b47d48f-26fe-49d8-8c74-0a3d91bb06b0', '***REMOVED***')
#      10 transport = Transport(session=session)
# ---> 11 bearer_client = Client(BEARER_ENDPOINT, transport=transport)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/site-packages/zeep/client.py:76, in Client.__init__(self, wsdl, wsse, transport, service_name, port_name, plugins, settings)
#      74     self.wsdl = wsdl
#      75 else:
# ---> 76     self.wsdl = Document(wsdl, self.transport, settings=self.settings)
#      77 self.wsse = wsse
#      78 self.plugins = plugins if plugins is not None else []
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/site-packages/zeep/wsdl/wsdl.py:86, in Document.__init__(self, location, transport, base, settings)
#      77 self._definitions = (
#      78     {}
#      79 )  # type: typing.Dict[typing.Tuple[str, str], "Definition"]
#      80 self.types = Schema(
#      81     node=None,
#      82     transport=self.transport,
#      83     location=self.location,
#      84     settings=self.settings,
#      85 )
# ---> 86 self.load(location)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/site-packages/zeep/wsdl/wsdl.py:89, in Document.load(self, location)
#      88 def load(self, location):
# ---> 89     document = self._get_xml_document(location)
#      91     root_definitions = Definition(self, document, self.location)
#      92     root_definitions.resolve_imports()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/site-packages/zeep/wsdl/wsdl.py:149, in Document._get_xml_document(self, location)
#     141 def _get_xml_document(self, location: typing.IO) -> etree._Element:
#     142     """Load the XML content from the given location and return an
#     143     lxml.Element object.
#     144
#    (...)
#     147
#     148     """
# --> 149     return load_external(
#     150         location, self.transport, self.location, settings=self.settings
#     151     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/site-packages/zeep/loader.py:89, in load_external(url, transport, base_url, settings)
#      87     if base_url:
#      88         url = absolute_location(url, base_url)
# ---> 89     content = transport.load(url)
#      90 return parse_xml(content, transport, base_url, settings=settings)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/site-packages/zeep/transports.py:122, in Transport.load(self, url)
#     119     if response:
#     120         return bytes(response)
# --> 122 content = self._load_remote_data(url)
#     124 if self.cache:
#     125     self.cache.add(url, content)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/site-packages/zeep/transports.py:136, in Transport._load_remote_data(self, url)
#     134 response = self.session.get(url, timeout=self.load_timeout)
#     135 with closing(response):
# --> 136     response.raise_for_status()
#     137     return response.content
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: ***REMOVED***

# %%
# SIAPE

from zeep import Transport, Client
from requests import Session
import requests

# Auth endpoint for token
BEARER_ENDPOINT = "***REMOVED***"
SOAP_ENDPOINT = "https://apigateway.conectagov.estaleiro.serpro.gov.br/api-consulta-siape/v1/consulta-siape"

# Get token
auth_response = requests.get(
   BEARER_ENDPOINT,
   auth=('9b47d48f-26fe-49d8-8c74-0a3d91bb06b0', '***REMOVED***'),
   headers={'Content-Type': 'application/x-www-form-urlencoded'}
)
print(auth_response.text)
token = auth_response.json()['access_token']  # Adjust based on response format

# Setup SOAP client with token
session = Session()
session.headers.update({'Authorization': f'Bearer {token}'})
transport = Transport(session=session)

# Create SOAP client
client = Client(SOAP_ENDPOINT, transport=transport)

# Make service calls
result = client.service.ConsultaDadosAfastamento()
# Out:
# ***REMOVED***
# ***REMOVED***
# ***REMOVED***
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 18
#      12 auth_response = requests.get(
#      13    BEARER_ENDPOINT,
#      14    auth=('9b47d48f-26fe-49d8-8c74-0a3d91bb06b0', '***REMOVED***'),
#      15    headers={'Content-Type': 'application/x-www-form-urlencoded'}
#      16 )
#      17 print(auth_response.text)
# ---> 18 token = auth_response.json()['access_token']  # Adjust based on response format
#      20 # Setup SOAP client with token
#      21 session = Session()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/lappis/lib/python3.11/site-packages/requests/models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
#SIAFI

BEARER_ENDPOINT = "***REMOVED***"
BEARER_KEY = "***REMOVED***"
BEARER_SECRET = "***REMOVED***"

import requests

def get_token(url, consumer_key, consumer_secret):
    data = {
        'grant_type': 'client_credentials'
    }

    response = requests.post(
        url,
        data=data,
        auth=(consumer_key, consumer_secret)
    )
    return response.json()

token_response = get_token(BEARER_ENDPOINT, BEARER_KEY, BEARER_SECRET)

# %%
print(token_response)
# Out:
# {'access_token': 'eyJ4NXQiOiJNalJqWkRRMU1EQmtPR1JqWW1Jek9EVmxaRFEzWkdFeU1EVTVabU5rWldVeU9XUmhPRFZpTnci***REMOVED***

# %%
SIAFI_ENDPOINT = "https://gateway.apiserpro.serpro.gov.br/api-integra-siafi/api/v2/nota-credito/113601/61201/2024/596765"
SIAFI_CREDENTIAL = "MjE1NTQyMDY4NDcuMTEzNjAxLlNJQUZJMjAyMw=="
def get_data(url, bearer_token, credential):
   headers = {
       'Authorization': f'Bearer {bearer_token}',
       'Content-Type': 'application/json',
       'x-credencial': credential,
   }
   response = requests.get(url, headers=headers)
   print(response.text)
   return response.json()

data = get_data(SIAFI_ENDPOINT, token_response.get('access_token'), SIAFI_CREDENTIAL)
print(data)
# Out:
# {"codigo":99,"mensagem":"Requisição inválida","erros":[{"code":"99","value":""}],"status":400}
# {'codigo': 99, 'mensagem': 'Requisição inválida', 'erros': [{'code': '99', 'value': ''}], 'status': 400}

# %%
from datetime import date
import time

start = date(2024, 1, 1)
end = date(2025, 1, 1)
d = start
while d < end:
    f = format(d, '%d%b%y').upper()
    print(f)
    data = get_data(SIAFI_ENDPOINT.format(date=f), token_response.get('access_token'), SIAFI_CREDENTIAL)
    print(data)
    time.sleep(10)
